# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
mse = [0, 5, 10, 20, 100, 200]

# %%
nombre_base_1 = "datos//dato_2023-06-04 18.25.14.091114_--can_prop=15--can_op=40--rango=3--max_add=3--min_ap=3__"
lista_archivos_1 = [nombre_base_1 + str(i) + ".txt" for i in range(0, 30)]

# %%
def obtener_array_string(lista):
    lista = lista.replace("[","").replace("]","").split(",")
    lista = [float(num) for num in lista]
    return np.array(lista)

def obtener_lista_archivo(nombre):
    archivo = open(nombre, "r")
    lista = archivo.readlines()
    archivo.close()
    nueva_lista = []
    for elemento in lista:
        nueva_lista.append(elemento.strip("\n"))
    return nueva_lista

# %%
def obtener_lista_grafico(lista_listas, indice):
    final = []
    for elemento in lista_listas:
        final.append(elemento[indice])
    return final

# %%
def obtener_datos(lista_archivos):
    mse = [0, 5, 10, 20, 100, 200]

    expansiones_fs_0 = []
    expansiones_fs_5 = []
    expansiones_fs_10 = []
    expansiones_fs_20 = []
    expansiones_fs_100 = []
    expansiones_fs_200 = []

    tiempo_fs_0 = []
    tiempo_fs_5 = []
    tiempo_fs_10 = []
    tiempo_fs_20 = []
    tiempo_fs_100 = []
    tiempo_fs_200 = []

    expansiones_fsd_0 = []
    expansiones_fsd_5 = []
    expansiones_fsd_10 = []
    expansiones_fsd_20 = []
    expansiones_fsd_100 = []
    expansiones_fsd_200 = []

    tiempo_fsd_0 = []
    tiempo_fsd_5 = []
    tiempo_fsd_10 = []
    tiempo_fsd_20 = []
    tiempo_fsd_100 = []
    tiempo_fsd_200 = []
    
    for nombre in lista_archivos:
        archivo = obtener_lista_archivo(nombre)
        for linea in archivo:
            if "Nodos Focal:" in linea:
                lista = linea.replace("Nodos Focal: ", "")
                lista = obtener_array_string(lista)
                expansiones_fs_0.append(lista[0])
                expansiones_fs_5.append(lista[1])
                expansiones_fs_10.append(lista[2])
                expansiones_fs_20.append(lista[3])
                expansiones_fs_100.append(lista[4])
                expansiones_fs_200.append(lista[5])
            elif "Nodos Focal Discrepancy:" in linea:
                lista = linea.replace("Nodos Focal Discrepancy: ", "")
                lista = obtener_array_string(lista)
                expansiones_fsd_0.append(lista[0])
                expansiones_fsd_5.append(lista[1])
                expansiones_fsd_10.append(lista[2])
                expansiones_fsd_20.append(lista[3])
                expansiones_fsd_100.append(lista[4])
                expansiones_fsd_200.append(lista[5])
            elif "Tiempo Focal:" in linea:
                lista = linea.replace("Tiempo Focal: ", "")
                lista = obtener_array_string(lista)
                tiempo_fs_0.append(lista[0])
                tiempo_fs_5.append(lista[1])
                tiempo_fs_10.append(lista[2])
                tiempo_fs_20.append(lista[3])
                tiempo_fs_100.append(lista[4])
                tiempo_fs_200.append(lista[5])
            elif "Tiempo Focal Discrepancy:" in linea:
                lista = linea.replace("Tiempo Focal Discrepancy: ", "")
                lista = obtener_array_string(lista)
                tiempo_fsd_0.append(lista[0])
                tiempo_fsd_5.append(lista[1])
                tiempo_fsd_10.append(lista[2])
                tiempo_fsd_20.append(lista[3])
                tiempo_fsd_100.append(lista[4])
                tiempo_fsd_200.append(lista[5])
    tiempos_fs = [tiempo_fs_0, tiempo_fs_5, tiempo_fs_10, tiempo_fs_20, tiempo_fs_100, tiempo_fs_200]
    tiempos_fsd = [tiempo_fsd_0, tiempo_fsd_5, tiempo_fsd_10, tiempo_fsd_20, tiempo_fsd_100, tiempo_fsd_200]
    expansiones_fs = [expansiones_fs_0, expansiones_fs_5, expansiones_fs_10, expansiones_fs_20, expansiones_fs_100, expansiones_fs_200]
    expansiones_fsd = [expansiones_fsd_0, expansiones_fsd_5, expansiones_fsd_10, expansiones_fsd_20, expansiones_fsd_100, expansiones_fsd_200]
    return (tiempos_fs, tiempos_fsd, expansiones_fs, expansiones_fsd)

# %%
tiempos_fs, tiempos_fsd, expansiones_fs, expansiones_fsd = obtener_datos(lista_archivos_1)

promedio_tiempo_fs = [np.mean(tiempo) for tiempo in tiempos_fs]
promedio_tiempo_fds = [np.mean(tiempo) for tiempo in tiempos_fsd]
promedio_exp_fs = [np.mean(exp) for exp in expansiones_fs]
promedio_exp_fds = [np.mean(exp) for exp in expansiones_fsd]

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
num_indice = 10
ax.plot([1,2,3,4,5,6], obtener_lista_grafico(tiempos_fs, num_indice), label = "FS", color = "red")
ax.plot([1,2,3,4,5,6], obtener_lista_grafico(tiempos_fsd, num_indice), label= "FDS", color = "blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Runtime (s)", fontsize=14)
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
num_indice = 10
ax.plot([1,2,3,4,5,6], obtener_lista_grafico(expansiones_fs, num_indice), label = "FS", color="red")
ax.plot([1,2,3,4,5,6], obtener_lista_grafico(expansiones_fsd, num_indice), label= "FDS",c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Expansions", fontsize=14)
plt.yscale("log")

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_tiempo_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_tiempo_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Runtime (s)", fontsize=14)
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_exp_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_exp_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Expansions", fontsize=14)
plt.yscale("log")

# %%
astar_h = []
astar_mse = []
for nombre in lista_archivos_1:
    archivo = obtener_lista_archivo(nombre)
    for linea in archivo:
        if "Nodos Astar:" in linea:
            lista = linea.replace("Nodos Astar: ", "")
            lista = obtener_array_string(lista)
            for h in lista:
                astar_h.append(h)
            for valor in mse:
                astar_mse.append(valor)

# %%
def funcion_sorted(lista):
    return lista[0]

# %%
astar = []
for i in range(0, len(astar_h)):
    h = astar_h[i]
    valor_mse = astar_mse[i]
    astar.append([h, valor_mse])
astar = sorted(astar, key=funcion_sorted)
astar_h = []
astar_mse = []
for valor in astar:
    h = valor[0]
    valor_mse = valor[1]
    astar_h.append(h)
    astar_mse.append(valor_mse)

# %%
plt.plot(astar_h, astar_mse)
plt.xlim(45, 70)
plt.ylim(0, 100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# # ejemplo 2

# %%
nombre_base_2 = "datos//dato_2023-06-08 16.47.48.834133_--can_prop=20--can_op=50--rango=3--max_add=2--min_ap=2__"
lista_archivos_2 = [nombre_base_2+ str(i) + ".txt" for i in range(0, 30)]

# %%
tiempos_fs, tiempos_fsd, expansiones_fs, expansiones_fsd = obtener_datos(lista_archivos_2)

promedio_tiempo_fs = [np.mean(tiempo) for tiempo in tiempos_fs]
promedio_tiempo_fds = [np.mean(tiempo) for tiempo in tiempos_fsd]
promedio_exp_fs = [np.mean(exp) for exp in expansiones_fs]
promedio_exp_fds = [np.mean(exp) for exp in expansiones_fsd]

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_tiempo_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_tiempo_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Runtime (s)", fontsize=14)
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_exp_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_exp_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Expansions", fontsize=14)
plt.yscale("log")

# %% [markdown]
# # ejemplo 3

# %%
nombre_base_3 = "datos//dato_2023-06-10 22.26.20.429733_--can_prop=12--can_op=50--rango=3--max_add=2--min_ap=2__"
lista_archivos_3 = [nombre_base_3+ str(i) + ".txt" for i in range(0, 30)]

# %%
tiempos_fs, tiempos_fsd, expansiones_fs, expansiones_fsd = obtener_datos(lista_archivos_3)

promedio_tiempo_fs = [np.mean(tiempo) for tiempo in tiempos_fs]
promedio_tiempo_fds = [np.mean(tiempo) for tiempo in tiempos_fsd]
promedio_exp_fs = [np.mean(exp) for exp in expansiones_fs]
promedio_exp_fds = [np.mean(exp) for exp in expansiones_fsd]

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_tiempo_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_tiempo_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Runtime (s)", fontsize=14)
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_exp_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_exp_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Expansions", fontsize=14)
plt.yscale("log")

# %% [markdown]
# # ejemplo 4

# %%
nombre_base_4 = "datos//dato_2023-06-11 00.16.47.797842_--can_prop=12--can_op=50--rango=3--max_add=2--min_ap=2__"
lista_archivos_4 = [nombre_base_4 + str(i) + ".txt" for i in range(0, 30)]

# %%
tiempos_fs, tiempos_fsd, expansiones_fs, expansiones_fsd = obtener_datos(lista_archivos_4)

promedio_tiempo_fs = [np.mean(tiempo) for tiempo in tiempos_fs]
promedio_tiempo_fds = [np.mean(tiempo) for tiempo in tiempos_fsd]
promedio_exp_fs = [np.mean(exp) for exp in expansiones_fs]
promedio_exp_fds = [np.mean(exp) for exp in expansiones_fsd]

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_tiempo_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_tiempo_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Runtime (s)", fontsize=14)
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_exp_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_exp_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Expansions", fontsize=14)
plt.yscale("log")

# %% [markdown]
# # ejemplo 5

# %%
nombre_base_5 = "datos//dato_2023-06-11 01.07.03.901083_--can_prop=18--can_op=40--rango=3--max_add=3--min_ap=2__"
lista_archivos_5 = [nombre_base_5 + str(i) + ".txt" for i in range(0, 30)]

# %%
tiempos_fs, tiempos_fsd, expansiones_fs, expansiones_fsd = obtener_datos(lista_archivos_5)

promedio_tiempo_fs = [np.mean(tiempo) for tiempo in tiempos_fs]
promedio_tiempo_fds = [np.mean(tiempo) for tiempo in tiempos_fsd]
promedio_exp_fs = [np.mean(exp) for exp in expansiones_fs]
promedio_exp_fds = [np.mean(exp) for exp in expansiones_fsd]

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_tiempo_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_tiempo_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Runtime (s)", fontsize=14)
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_exp_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_exp_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Expansions", fontsize=14)
plt.yscale("log")

# %% [markdown]
# # ejemplo 6 --------------------------

# %%
nombre_base_6= "datos//dato_2023-06-17 13.29.45.609205_--can_prop=15--can_op=40--rango=3--max_add=3--min_ap=2__"
lista_archivos_6 = [nombre_base_6 + str(i) + ".txt" for i in range(0, 30)]

# %%
tiempos_fs, tiempos_fsd, expansiones_fs, expansiones_fsd = obtener_datos(lista_archivos_6)

promedio_tiempo_fs = [np.mean(tiempo) for tiempo in tiempos_fs]
promedio_tiempo_fds = [np.mean(tiempo) for tiempo in tiempos_fsd]
promedio_exp_fs = [np.mean(exp) for exp in expansiones_fs]
promedio_exp_fds = [np.mean(exp) for exp in expansiones_fsd]
# Out:
# C:\Users\Anais\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Anais\anaconda3\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_tiempo_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_tiempo_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Runtime (s)", fontsize=14)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       2 ax.plot([1,2,3,4,5,6], promedio_tiempo_fs, label="FS", c="red")
#       3 ax.plot([1,2,3,4,5,6], promedio_tiempo_fds, label="FDS", c="blue")
# ----> 4 ax.set_xticks([1,2,3,4,5,6], mse)
#       5 ax.legend(fontsize=14)
#       6 ax.set_xlabel("Heuristic MSE", fontsize=14)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:2080, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2078 result = self._set_tick_locations(ticks, minor=minor)
#    2079 if labels is not None:
# -> 2080     self.set_ticklabels(labels, minor=minor, **kwargs)
# ...

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_exp_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_exp_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Expansions", fontsize=14)
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       2 ax.plot([1,2,3,4,5,6], promedio_exp_fs, label="FS", c="red")
#       3 ax.plot([1,2,3,4,5,6], promedio_exp_fds, label="FDS", c="blue")
# ----> 4 ax.set_xticks([1,2,3,4,5,6], mse)
#       5 ax.legend(fontsize=14)
#       6 ax.set_xlabel("Heuristic MSE", fontsize=14)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:2080, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2078 result = self._set_tick_locations(ticks, minor=minor)
#    2079 if labels is not None:
# -> 2080     self.set_ticklabels(labels, minor=minor, **kwargs)
# ...

# %% [markdown]
# # ejemplo 7

# %%
nombre_base_7 = "datos//dato_2023-06-17 13.50.10.705476_--can_prop=15--can_op=40--rango=3--max_add=3--min_ap=2__"
lista_archivos_7 = [nombre_base_7 + str(i) + ".txt" for i in range(0, 30)]

# %%
tiempos_fs, tiempos_fsd, expansiones_fs, expansiones_fsd = obtener_datos(lista_archivos_7)

promedio_tiempo_fs = [np.mean(tiempo) for tiempo in tiempos_fs]
promedio_tiempo_fds = [np.mean(tiempo) for tiempo in tiempos_fsd]
promedio_exp_fs = [np.mean(exp) for exp in expansiones_fs]
promedio_exp_fds = [np.mean(exp) for exp in expansiones_fsd]

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_tiempo_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_tiempo_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Runtime (s)", fontsize=14)
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_exp_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_exp_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Expansions", fontsize=14)
plt.yscale("log")

# %% [markdown]
# # ejemplo 8

# %%
nombre_base_8 = "datos//dato_2023-06-17 18.37.09.982693_--can_prop=15--can_op=40--rango=3--max_add=3--min_ap=2__"
lista_archivos_8 = [nombre_base_8 + str(i) + ".txt" for i in range(0, 30)]

# %%
tiempos_fs, tiempos_fsd, expansiones_fs, expansiones_fsd = obtener_datos(lista_archivos_8)

promedio_tiempo_fs = [np.mean(tiempo) for tiempo in tiempos_fs]
promedio_tiempo_fds = [np.mean(tiempo) for tiempo in tiempos_fsd]
promedio_exp_fs = [np.mean(exp) for exp in expansiones_fs]
promedio_exp_fds = [np.mean(exp) for exp in expansiones_fsd]

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_tiempo_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_tiempo_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Runtime (s)", fontsize=14)
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_exp_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_exp_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Expansions", fontsize=14)
plt.yscale("log")

# %% [markdown]
# # EJEMPLO 9

# %%
nombre_base_9 = "datos//dato_2023-07-14 17.46.19.329259_--can_prop=15--can_op=70--rango=3--max_add=3--min_ap=2__"
lista_archivos_9 = [nombre_base_9 + str(i) + ".txt" for i in range(0, 30)]
# factor de expansión: 2

# %%
tiempos_fs, tiempos_fsd, expansiones_fs, expansiones_fsd = obtener_datos(lista_archivos_9)

promedio_tiempo_fs = [np.mean(tiempo) for tiempo in tiempos_fs]
promedio_tiempo_fds = [np.mean(tiempo) for tiempo in tiempos_fsd]
promedio_exp_fs = [np.mean(exp) for exp in expansiones_fs]
promedio_exp_fds = [np.mean(exp) for exp in expansiones_fsd]

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_tiempo_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_tiempo_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Runtime (s)", fontsize=14)
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
fig,ax = plt.subplots(dpi=144, figsize = [6,4])
ax.plot([1,2,3,4,5,6], promedio_exp_fs, label="FS", c="red")
ax.plot([1,2,3,4,5,6], promedio_exp_fds, label="FDS", c="blue")
ax.set_xticks([1,2,3,4,5,6], mse)
ax.legend(fontsize=14)
ax.set_xlabel("Heuristic MSE", fontsize=14)
ax.set_ylabel("Expansions", fontsize=14)
plt.yscale("log")
