# %%
from funciones_graficos import graficar

# %% [markdown]
# # ej 1

# %%
ejemplo1_w15 = "dato_2023-08-31 21.47.31.937101_--can_prop=13--can_op=80--rango=3--max_add=2--min_ap=3--weight=1.5"
graficar(ejemplo1_w15, 1.5, 15, True)

# %%
ejemplo1_w2 = "dato_2023-08-31 21.47.31.937101_--can_prop=13--can_op=80--rango=3--max_add=2--min_ap=3--weight=2"
graficar(ejemplo1_w2, 2, 15, True)

# %%
ejemplo1_w4 = "dato_2023-08-31 21.47.31.937101_--can_prop=13--can_op=80--rango=3--max_add=2--min_ap=3--weight=4"
graficar(ejemplo1_w4, 4, 15, True)
