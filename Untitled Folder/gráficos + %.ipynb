# %%
from funciones_graficos import graficar

# %% [markdown]
# # ej 1

# %%
ejemplo1_w15 = "dato_2023-09-08 15.25.57.150078_--can_prop=17--can_op=80--rango=3--max_add=2--min_ap=3--weight=1.5"
graficar(ejemplo1_w15, 1.5, 30)

# %%
ejemplo1_w2 = "dato_2023-09-08 15.25.57.150078_--can_prop=17--can_op=80--rango=3--max_add=2--min_ap=3--weight=2"
graficar(ejemplo1_w2, 2, 30, True)

# %%
ejemplo1_w4 = "dato_2023-09-08 15.25.57.150078_--can_prop=17--can_op=80--rango=3--max_add=2--min_ap=3--weight=4"
graficar(ejemplo1_w4, 4, 30, True)

# %% [markdown]
# # ej 2

# %%
ejemplo2_w15 = "dato_2023-09-10 17.31.22.689411_--can_prop=15--can_op=80--rango=3--max_add=6--min_ap=2--weight=1.5"
graficar(ejemplo2_w15, 1.5, 30)

# %%
ejemplo2_w2 = "dato_2023-09-10 17.31.22.689411_--can_prop=15--can_op=80--rango=3--max_add=6--min_ap=2--weight=2"
graficar(ejemplo2_w2, 2, 30)

# %%
ejemplo2_w4 = "dato_2023-09-10 17.31.22.689411_--can_prop=15--can_op=80--rango=3--max_add=6--min_ap=2--weight=4"
graficar(ejemplo2_w4, 4, 30, True)

# %% [markdown]
# # ej 3

# %%
ejemplo3_w15 = "dato_2023-09-10 17.10.58.108021_--can_prop=13--can_op=100--rango=3--max_add=3--min_ap=3--weight=1.5"
graficar(ejemplo3_w15, 1.5, 30)

# %%
ejemplo3_w2 = "dato_2023-09-10 17.10.58.108021_--can_prop=13--can_op=100--rango=3--max_add=3--min_ap=3--weight=2"
graficar(ejemplo3_w2, 2, 30)

# %%
ejemplo3_w4 = "dato_2023-09-10 17.10.58.108021_--can_prop=13--can_op=100--rango=3--max_add=3--min_ap=3--weight=4"
graficar(ejemplo3_w4, 4, 30)

# %% [markdown]
# # ej 4

# %%
ejemplo4_w15 = "dato_2023-09-10 17.23.28.597440_--can_prop=14--can_op=70--rango=3--max_add=2--min_ap=3--weight=1.5"
graficar(ejemplo4_w15, 1.5, 30)

# %%
ejemplo4_w2 = "dato_2023-09-10 17.23.28.597440_--can_prop=14--can_op=70--rango=3--max_add=2--min_ap=3--weight=2"
graficar(ejemplo4_w2, 2, 30)

# %%
ejemplo4_w4 = "dato_2023-09-10 17.23.28.597440_--can_prop=14--can_op=70--rango=3--max_add=2--min_ap=3--weight=4"
graficar(ejemplo4_w4, 4, 30)
