# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
def cargar(archivo):
    file = open(archivo, "rb")
    clase = pickle.load(file)
    file.close()
    return clase

mse_values = [0, 2.5, 5, 10, 20, 100, 200]

# %%
grafo5 = cargar("grafos//grafo_2023-10-29 22.59.49.274734_--can_prop=20--can_op=500--rango=5--max_add=3--min_ap=10.pickle")

# %%
def lista_de_lista(n):
    lista = []
    for i in range(0, n):
        lista.append([])
    return lista

def eliminar_vacias(lista):
    final = []
    for elemento in lista:
        if len(elemento) > 0:
            final.append(elemento)
    return final

# %%
mse_k2 = lista_de_lista(100)
mse_k4 = lista_de_lista(100)
i = 1 # mse = 2.5
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    indice = int(h_perfect)
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    mse_k2[indice].append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    mse_k4[indice].append(err_k4)
mse_k2 = eliminar_vacias(mse_k2)
mse_k4 = eliminar_vacias(mse_k4)
mean_mse_k2 = [np.mean(mse) for mse in mse_k2]
mean_mse_k4 = [np.mean(mse) for mse in mse_k4]
h_perfect = [i for i in range(0, len(mean_mse_k2))]

fig,ax = plt.subplots(dpi=144, figsize = [10,4])
ax.plot(h_perfect, mean_mse_k2, label="k = 2")
ax.plot(h_perfect, mean_mse_k4, label = "k = 4")
ax.set_title(f"MSE = {mse_values[i]}", size=20)
ax.set_xlabel(r"$h*$", size=20)
ax.set_ylabel(r"$\overline{(h_{nn} - h*)^2}$", size=20)
ax.legend(fontsize=15)

# %%
len_mse_k2 = [len(mse) for mse in mse_k2]
len_mse_k4 = [len(mse) for mse in mse_k4]
len_mse_k4
# Out:
# [1, 16, 188, 1951, 18509, 134752, 469960, 382425, 40109, 641, 5, 2]

# %%
mse_k2 = lista_de_lista(100)
mse_k4 = lista_de_lista(100)
i = 2 # mse = 5
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    indice = int(h_perfect)
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    mse_k2[indice].append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    mse_k4[indice].append(err_k4)
mse_k2 = eliminar_vacias(mse_k2)
mse_k4 = eliminar_vacias(mse_k4)
mean_mse_k2 = [np.median(mse) for mse in mse_k2]
mean_mse_k4 = [np.median(mse) for mse in mse_k4]
h_perfect = [i for i in range(0, len(mean_mse_k2))]

fig,ax = plt.subplots(dpi=144, figsize = [10,4])
ax.plot(h_perfect, mean_mse_k2, label="k = 2")
ax.plot(h_perfect, mean_mse_k4, label = "k = 4")
ax.set_title(f"MSE = {mse_values[i]}", size=20)
ax.set_xlabel(r"$h*$", size=20)
ax.set_ylabel(r"$\overline{(h_{nn} - h*)^2}$", size=20)
ax.legend(fontsize=15)

len_mse_k2 = [len(mse) for mse in mse_k2]
len_mse_k4 = [len(mse) for mse in mse_k4]
len_mse_k4
# Out:
# [1, 16, 188, 1951, 18509, 134752, 469960, 382425, 40109, 641, 5, 2]

# %%
mse_k2 = lista_de_lista(100)
mse_k4 = lista_de_lista(100)
i = 3 # mse = 10
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    indice = int(h_perfect)
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    mse_k2[indice].append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    mse_k4[indice].append(err_k4)
mse_k2 = eliminar_vacias(mse_k2)
mse_k4 = eliminar_vacias(mse_k4)
mean_mse_k2 = [np.mean(mse) for mse in mse_k2]
mean_mse_k4 = [np.mean(mse) for mse in mse_k4]
h_perfect = [i for i in range(0, len(mean_mse_k2))]

fig,ax = plt.subplots(dpi=144, figsize = [10,4])
ax.plot(h_perfect, mean_mse_k2, label="k = 2")
ax.plot(h_perfect, mean_mse_k4, label = "k = 4")
ax.set_title(f"MSE = {mse_values[i]}", size=20)
ax.set_xlabel(r"$h*$", size=20)
ax.set_ylabel(r"$\overline{(h_{nn} - h*)^2}$", size=20)
ax.legend(fontsize=15)

# %%
mse_k2 = lista_de_lista(100)
mse_k4 = lista_de_lista(100)
i = 4 # mse = 20
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    indice = int(h_perfect)
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    mse_k2[indice].append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    mse_k4[indice].append(err_k4)
mse_k2 = eliminar_vacias(mse_k2)
mse_k4 = eliminar_vacias(mse_k4)
mean_mse_k2 = [np.mean(mse) for mse in mse_k2]
mean_mse_k4 = [np.mean(mse) for mse in mse_k4]
h_perfect = [i for i in range(0, len(mean_mse_k2))]

fig,ax = plt.subplots(dpi=144, figsize = [10,4])
ax.plot(h_perfect, mean_mse_k2, label="k = 2")
ax.plot(h_perfect, mean_mse_k4, label = "k = 4")
ax.set_title(f"MSE = {mse_values[i]}", size=20)
ax.set_xlabel(r"$h*$", size=20)
ax.set_ylabel(r"$\overline{(h_{nn} - h*)^2}$", size=20)
ax.legend(fontsize=15)

# %%
mse_k2 = lista_de_lista(100)
mse_k4 = lista_de_lista(100)
i = 5 # mse = 100
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    indice = int(h_perfect)
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    mse_k2[indice].append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    mse_k4[indice].append(err_k4)
mse_k2 = eliminar_vacias(mse_k2)
mse_k4 = eliminar_vacias(mse_k4)
mean_mse_k2 = [np.mean(mse) for mse in mse_k2]
mean_mse_k4 = [np.mean(mse) for mse in mse_k4]
h_perfect = [i for i in range(0, len(mean_mse_k2))]

fig,ax = plt.subplots(dpi=144, figsize = [10,4])
ax.plot(h_perfect, mean_mse_k2, label="k = 2")
ax.plot(h_perfect, mean_mse_k4, label = "k = 4")
ax.set_title(f"MSE = {mse_values[i]}", size=20)
ax.set_xlabel(r"$h*$", size=20)
ax.set_ylabel(r"$\overline{(h_{nn} - h*)^2}$", size=20)
ax.legend(fontsize=15)

# %%
mse_k2 = lista_de_lista(100)
mse_k4 = lista_de_lista(100)
i = 6 # mse = 200
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    indice = int(h_perfect)
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    mse_k2[indice].append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    mse_k4[indice].append(err_k4)
mse_k2 = eliminar_vacias(mse_k2)
mse_k4 = eliminar_vacias(mse_k4)
mean_mse_k2 = [np.mean(mse) for mse in mse_k2]
mean_mse_k4 = [np.mean(mse) for mse in mse_k4]
h_perfect = [i for i in range(0, len(mean_mse_k2))]

fig,ax = plt.subplots(dpi=144, figsize = [10,4])
ax.plot(h_perfect, mean_mse_k2, label="k = 2")
ax.plot(h_perfect, mean_mse_k4, label = "k = 4")
ax.set_title(f"MSE = {mse_values[i]}", size=20)
ax.set_xlabel(r"$h*$", size=20)
ax.set_ylabel(r"$\overline{(h_{nn} - h*)^2}$", size=20)
ax.legend(fontsize=15)

# %%
total_k2 = []
total_k4 = []
i = 1 # mse = 2.5
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    total_k2.append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    total_k4.append(err_k4)
print(np.mean(total_k2), np.mean(total_k4))
# Out:
# 2.502287961500002 2.5006665970764974

# %%
total_k2 = []
total_k4 = []
i = 2 # mse = 5
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    total_k2.append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    total_k4.append(err_k4)
print(np.median(total_k2), np.median(total_k4))
# Out:
# 1.9366642812815702 1.3239584154392645

# %%
total_k2 = []
total_k4 = []
i = 3 # mse = 10
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    total_k2.append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    total_k4.append(err_k4)
print(np.median(total_k2), np.median(total_k4))
# Out:
# 3.896923838053659 2.655092888534027

# %%
total_k2 = []
total_k4 = []
i = 4 # mse = 20
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    total_k2.append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    total_k4.append(err_k4)
print(np.median(total_k2), np.median(total_k4))
# Out:
# 7.748023229462198 5.279586202929451

# %%
total_k2 = []
total_k4 = []
i = 5 # mse = 100
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    total_k2.append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    total_k4.append(err_k4)
print(np.median(total_k2), np.median(total_k4))
# Out:
# 38.82768091054448 26.404754674544726

# %%
total_k2 = []
total_k4 = []
i = 6 # mse = 200
for estado in grafo5.mse_provisorio_k2[0]:
    h_perfect = grafo5.mse_provisorio_k2[0][estado]
    # k = 2
    h_nn = grafo5.mse_provisorio_k2[i][estado]
    err_k2 = (h_nn - h_perfect)**2
    total_k2.append(err_k2)
    # k = 4
    h_nn = grafo5.mse_provisorio_k4[i][estado]
    err_k4 = (h_nn - h_perfect)**2
    total_k4.append(err_k4)
print(np.median(total_k2), np.median(total_k4))
# Out:
# 77.28117876627414 52.993115423817926

# %%
fig,ax = plt.subplots(dpi=144, figsize = [10,4])
for i in range(1, 7):
    mse_k2 = lista_de_lista(100)
    for estado in grafo5.mse_provisorio_k2[0]:
        h_perfect = grafo5.mse_provisorio_k2[0][estado]
        indice = int(h_perfect)
        h_nn = grafo5.mse_provisorio_k2[i][estado]
        err_k2 = (h_nn - h_perfect)**2
        mse_k2[indice].append(err_k2)
    mse_k2 = eliminar_vacias(mse_k2)
    mean_mse_k2 = [np.mean(mse) for mse in mse_k2]
    h_perfect = [i for i in range(0, len(mean_mse_k2))]
    ax.plot(h_perfect, mean_mse_k2, label=f"MSE = {mse_values[i]}")
ax.set_title("k = 2", size=20)
ax.set_xlabel(r"$h*$", size=20)
ax.set_ylabel(r"$\overline{(h_{nn} - h*)^2}$", size=20)
ax.legend(fontsize=15)

# %%
fig,ax = plt.subplots(dpi=144, figsize = [10,4])
for i in range(1, 7):
    mse_k4 = lista_de_lista(100)
    for estado in grafo5.mse_provisorio_k4[0]:
        h_perfect = grafo5.mse_provisorio_k4[0][estado]
        indice = int(h_perfect)
        h_nn = grafo5.mse_provisorio_k4[i][estado]
        err_k4 = (h_nn - h_perfect)**2
        mse_k4[indice].append(err_k4)
    mse_k4 = eliminar_vacias(mse_k4)
    mean_mse_k4 = [np.mean(mse) for mse in mse_k4]
    h_perfect = [i for i in range(0, len(mean_mse_k4))]
    ax.plot(h_perfect, mean_mse_k4, label=f"MSE = {mse_values[i]}")
ax.set_title("k = 4", size=20)
ax.set_xlabel(r"$h*$", size=20)
ax.set_ylabel(r"$\overline{(h_{nn} - h*)^2}$", size=20)
ax.legend(fontsize=15)

# %%
fig,ax = plt.subplots(dpi=144, figsize = [10,4])
for i in range(1, 7):
    mse_k4 = lista_de_lista(100)
    for estado in grafo5.mse_provisorio_k4[0]:
        h_perfect = grafo5.mse_provisorio_k4[0][estado]
        indice = int(h_perfect)
        h_nn = grafo5.mse_provisorio_k4[i][estado]
        err_k4 = (h_nn - h_perfect)**2
        mse_k4[indice].append(err_k4)
    mse_k4 = eliminar_vacias(mse_k4)
    mean_mse_k4 = [np.mean(mse) for mse in mse_k4]
    h_perfect = [i for i in range(0, len(mean_mse_k4))]
    ax.plot(h_perfect, mean_mse_k4, label=f"MSE = {mse_values[i]}")
ax.set_title("k = 4", size=20)
ax.set_xlabel(r"$h*$", size=20)
ax.set_ylabel(r"$\overline{(h_{nn} - h*)^2}$", size=20)
ax.set_ylim(0, 500)
ax.legend(fontsize=15)
